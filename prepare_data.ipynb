# %%
import numpy as np
import torch
import torch.nn as nn
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
image_path = 'bus.jpg'
img = plt.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Tắt trục
plt.show()

# %%
model = YOLO('yolov8s.pt')

# %%
# model.train(data = 'coco128.yaml', epochs = 5, project='coco_128', batch=8)
# %matplotlib inline
# !python yolov8_KD/KD_training.py --model yolov8s.pt --teacher yolov8l.pt --project coco_128  --data coco128.yaml --epochs 5 --batch 8 --device 0
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.10 torch-2.0.0 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11172MiB)
# ...
